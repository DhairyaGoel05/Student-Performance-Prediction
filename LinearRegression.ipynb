# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Student-Performance-csv_T4qDx.csv")

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.tail()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# max                            9.000000         100.000000

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Hours Studied                         int64
# Previous Scores                       int64
# Extracurricular Activities           object
# Sleep Hours                           int64
# Sample Question Papers Practiced      int64
# Performance Index                   float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
le=LabelEncoder()
df['Extracurricular Activities']=le.fit_transform(df['Extracurricular Activities'])

# %%
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...                                ...                ...
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0
#
# [10000 rows x 6 columns]

# %%
x=df[["Hours Studied","Previous Scores","Extracurricular Activities","Sleep Hours"	,"Sample Question Papers Practiced"]]

# %%
y=df['Performance Index']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2)

# %%
x_train
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 3153              9               52                           1            9
# 5829              2               99                           1            9
# 2212              4               73                           1            8
# 5213              6               68                           1            7
# 2111              2               90                           0            6
# ...             ...              ...                         ...          ...
# 1777              5               57                           0            9
# 4381              5               95                           0            8
# 2343              2               90                           0            5
# 9764              6               64                           1            4
# 2142              8               84                           1            9
#
#       Sample Question Papers Practiced
# 3153                                 2
# 5829                                 8
# 2212                                 8
# 5213                                 2
# 2111                                 0
# ...                                ...
# 1777                                 1
# 4381                                 1
# 2343                                 9
# 9764                                 4
# 2142                                 6
#
# [8000 rows x 5 columns]

# %%
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
import pickle
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
model=LinearRegression()
model.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(x_test_scaled)

# %%
x_test_scaled
# Out:
# array([[ 0.41652609,  0.66982965,  0.98019606, -1.44409294, -1.21411916],
#        [ 1.1889435 ,  0.49841542, -1.02020406,  0.30208957, -1.56731746],
#        [ 1.1889435 ,  0.21272505, -1.02020406, -1.44409294, -1.21411916],
#        ...,
#        [ 1.5751522 ,  1.06979617,  0.98019606, -0.27997126, -0.86092086],
#        [ 1.1889435 ,  1.58403884, -1.02020406, -0.27997126, -1.56731746],
#        [-1.51451743,  0.3270012 ,  0.98019606, -1.44409294, -1.21411916]])

# %%
model.predict([[0.41652609,  0.66982965,  0.98019606, -1.44409294, -1.21411916]])
# Out:
# array([68.64898892])

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 1.6349173728509832

# %%
r2_score(y_test,y_predict)
# Out:
# 0.9885837265818351

# %%
import pickle
with open("student_lr_model.pkl",'wb') as file:
  pickle.dump((model,scaler,le),file)
